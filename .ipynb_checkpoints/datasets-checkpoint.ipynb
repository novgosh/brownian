# %%
# %pylab inline

import xlrd
import numpy as np
import scipy as sp

import scipy.optimize as spo
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a = [1, 2, 3]
b = [4, 5, 6, 7]
print(list(zip(a, b)))
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
def row_to_array(row):
    return list(map(lambda cell: float(cell.value) if cell.value else cell.value, row))

def is_header(row, template):
    for (value, cell) in zip(template, row):
        if value != cell.value:
            return False
    return True

# %%
ARSNOC_HEADER = ['a', 'x', 'y'] 

def parse_arsnoc_sheet(sheet):
    track = []
    
    is_first = None
    
    for pos in range(sheet.nrows):
        row = sheet.row(pos)
        if is_first is None:
            if is_header(row, ARSNOC_HEADER):
                is_first = True
        else:
            row = row_to_array(row[:3])
            if is_first:
                r = row[0]
                is_first = False
            track.append([r] + row[1:])
    return np.array(track)        

def parse_arsnoc_book(book):
    result = []
    for sheet in book.sheets():
        current_track = parse_arsnoc_sheet(sheet)
        if current_track.shape[0] != 0:
            result.append(current_track)
            print(current_track.shape)
            
    return [result] 
        
data = []
for i in range(2, 15):
    file_name = './data/arsnoc{}cnfoc.xls'.format(i)
    print(file_name)
    book = xlrd.open_workbook(file_name)
    data.extend(parse_arsnoc_book(book))
# Out:
# ./data/arsnoc2cnfoc.xls
# (119, 3)
# (29, 3)
# (119, 3)
# (33, 3)
# (121, 3)
# ./data/arsnoc3cnfoc.xls
# (122, 3)
# (49, 3)
# (120, 3)
# (55, 3)
# (241, 3)
# (120, 3)
# ./data/arsnoc4cnfoc.xls
# (122, 3)
# (119, 3)
# (120, 3)
# (120, 3)
# (82, 3)
# (58, 3)
# (120, 3)
# (120, 3)
# (20, 3)
# (55, 3)
# (120, 3)
# ./data/arsnoc5cnfoc.xls
# (80, 3)
# (65, 3)
# (30, 3)
# (113, 3)
# (71, 3)
# (122, 3)
# (49, 3)
# (121, 3)
# (100, 3)
# (36, 3)
# (121, 3)
# (123, 3)
# (121, 3)
# ./data/arsnoc6cnfoc.xls
# (119, 3)
# (119, 3)
# (120, 3)
# (120, 3)
# (108, 3)
# (120, 3)
# (118, 3)
# (120, 3)
# (119, 3)
# (70, 3)
# (67, 3)
# (99, 3)
# ./data/arsnoc7cnfoc.xls
# ./data/arsnoc8cnfoc.xls
# (120, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (112, 3)
# (119, 3)
# (119, 3)
# (120, 3)
# (90, 3)
# (74, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (33, 3)
# (121, 3)
# (120, 3)
# (120, 3)
# (119, 3)
# ./data/arsnoc9cnfoc.xls
# (120, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (121, 3)
# (85, 3)
# (119, 3)
# (94, 3)
# (120, 3)
# (120, 3)
# (110, 3)
# (118, 3)
# (29, 3)
# (119, 3)
# ./data/arsnoc10cnfoc.xls
# (54, 3)
# (121, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# ./data/arsnoc11cnfoc.xls
# (94, 3)
# (119, 3)
# (120, 3)
# (120, 3)
# (78, 3)
# (84, 3)
# (86, 3)
# (120, 3)
# (120, 3)
# ./data/arsnoc12cnfoc.xls
# (120, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (75, 3)
# (118, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (119, 3)
# (120, 3)
# (120, 3)
# (89, 3)
# (119, 3)
# ./data/arsnoc13cnfoc.xls
# (119, 3)
# (120, 3)
# (53, 3)
# (76, 3)
# (98, 3)
# (28, 3)
# ./data/arsnoc14cnfoc.xls
# (120, 3)
# (120, 3)
# (119, 3)
# (119, 3)
# (119, 3)
# (120, 3)
# (119, 3)
# (120, 3)
# (120, 3)
# (120, 3)
# (119, 3)

# %%
HEADER   = ['клетка 1', "Area", "XM", "YM", "XStart", "YStart"]
NEW_CELL = ['клетка 2', '', '', '', '', '']


def is_empty(row):
    for cell in row:
        if cell.value:
            return False
    return True

def is_new_cell(row):
    for i, cell in enumerate(row):
        if NEW_CELL[i] != cell.value:
            return False
    return True

def parse_sheet(sheet):
    data = []
    cell = []
    track = []
    
    assert is_header(sheet.row(0), HEADER)
    
    for pos in range(1, sheet.nrows):
        row = sheet.row(pos)
        if is_empty(row):
            if track:
                cell.append(np.array(track))
                track = []
        elif is_new_cell(row):
            if track:
                cell.append(np.array(track))
                track = []

            data.append(cell)
            cell = []
        else:
            track.append(row_to_array(row))
    if track:
        cell.append(np.array(track))
        track = []

    if cell:
        data.append(cell)
        
    return data

def parse_new_tracks(book):
    data = []
    for sheet in book.sheets():
        data.extend(parse_sheet(sheet))
    return data

# %%
book = xlrd.open_workbook('./data/tracks_new.xls')
data = parse_new_tracks(book)

print('Data Length: {}'.format(len(data)))
for cell in data:
    print('\tCell Length: {}'.format(len(cell)))
# Out:
# Data Length: 8
# 	Cell Length: 20
# 	Cell Length: 21
# 	Cell Length: 10
# 	Cell Length: 11
# 	Cell Length: 15
# 	Cell Length: 7
# 	Cell Length: 10
# 	Cell Length: 10

# %%
cell = data[1]

for track in cell:
    szs = np.pi * np.sum((track[:, 2:4] - track[:, 4:6]) ** 2, 1)
    plot(arange(len(szs)), szs)
    plot(arange(len(szs)), track[:, 1])
    show()

# %%
cell = data[0]

fig, ax = plt.subplots()
for track in cell:
    szs = np.pi * np.sum((track[:, 2:4] - track[:, 4:6]) ** 2, 1)
    for i in range(track.shape[0]):
        ax.add_artist(Circle(track[i, 2:4], np.sqrt(track[i, 1] / np.pi), color='r'))
    scatter(track[:, 2], track[:, 3], s=np.sqrt(track[:, 1] / np.pi))
show()

# %%
for cell in data:
    length = np.amax(list(map(lambda track: track.shape[0], cell)))

    ys, ss = [], []
    for i in range(length // 2):
        cur = []
        for track in cell:
            if track.shape[0] > i:
                cur.append(np.sum((track[0, 2:4] - track[i, 2:4]) ** 2))
        ys.append(np.mean(cur))
        ss.append(len(cur))
    plot(arange(len(ys)), ys)
    figure()

# %%
def t_function(x, alpha, beta):
    return beta * x**alpha

for cell in data:
    for track in cell:
        ys, ss = [], []
        for i in range(track.shape[0]):
            cur = []
            for j in range(track.shape[0] - i):
                cur.append(np.sum((track[j, 1:3] - track[j + i, 1:3]) ** 2))
            ys.append(np.mean(cur))
            ss.append(len(cur))
        ys = np.array(ys)
        
        xs = arange(len(ys))[:len(ys) // 2]
        ys = ys[xs]
            
        popt, _ = spo.curve_fit(t_function, xs, ys, [1, 1])
        
        print(popt)
        plot(xs, ys)
        plot(xs, t_function(xs, *popt))
        show()
# Out:
# [  0.84466433  10.01143355]
# /home/george/envs/mlenv/lib/python3.5/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in power
#   from ipykernel import kernelapp as app
# [ 1.50234229  0.20074524]
# [ 1.03158713  3.72666783]
# [  1.02285228  13.66446735]
# [ 0.78253485  3.39163155]
# [ 0.37943193  5.42066565]
# [  0.36376786  11.73602123]
# [ 1.34521387  1.00990885]
# [ 0.50665887  7.48506829]
# [  1.4850351   38.60338706]
# [ 0.55943537  5.53590091]
# [ 1.06426533  3.19701548]
# [ 1.49021511  1.14753133]
# [ 0.69675136  3.06732138]
# [ 1.25917969  0.16838823]
# [  0.78911422  14.06388858]
# [  0.59050374  17.75615038]
# [ 1.34626391  0.16944426]
# [ 0.30601838  7.58777463]
# [  1.31637968  14.71462543]
# [ 0.24995365  7.57123186]
# [ 1.03205094  1.03853688]
# [ 1.13803022  5.09156517]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-09553f5c2e54> in <module>()
#       8             cur = []
#       9             for j in range(track.shape[0] - i):
# ---> 10                 cur.append(np.sum((track[j, 1:3] - track[j + i, 1:3]) ** 2))
#      11             ys.append(np.mean(cur))
#      12             ss.append(len(cur))
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')
