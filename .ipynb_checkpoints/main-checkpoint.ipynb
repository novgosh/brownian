# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import time
import sys

import scipy as sp
import scipy.optimize

# %%
def plot_generation(generation, *args):
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.plot(generation[:, 0], generation[:, 1], generation[:, 2], *args)
    return ax

# %%
def fuck_numpy(array):
    print('Fuck det shit')
    
a = np.zeros([0, 3])
np.apply_along_axis(fuck_numpy, 1, a)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-181-388755960fd0> in <module>()
#       3
#       4 a = np.zeros([0, 3])
# ----> 5 np.apply_along_axis(fuck_numpy, 1, a)
#
# /home/george/envs/mlenv/lib/python3.5/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#      89     outshape = asarray(arr.shape).take(indlist)
#      90     i.put(indlist, ind)
# ---> 91     res = func1d(arr[tuple(i.tolist())], *args, **kwargs)
#      92     #  if res is a number, then we have a smaller output array
#      93     if isscalar(res):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
print(tracks[0].shape, remove_same(tracks[0]).shape)

print(remove_same(tracks[0, :, :]))
# Out:
# (1000, 3) (974, 3)
# [[ -1.00014314e-07  -1.74290621e-06   8.76004784e-06]
#  [ -7.09365055e-08  -1.90320792e-06   8.40475676e-06]
#  [ -2.13947090e-07  -1.72057677e-06   8.09085545e-06]
#  ...,
#  [ -9.90287428e-07  -7.83037166e-06   4.78255213e-06]
#  [ -9.50738241e-07  -8.02789453e-06   4.33493924e-06]
#  [ -1.07650775e-06  -8.08331445e-06   4.45639584e-06]]

# %%
N = 3
ETA = 1.0e-3
kB = 1.38e-23
T = 293

preD = kB * T / (3 * np.pi * ETA)

R = 10 * 1e-6
H = 1.5 * 1e-5
MIN_D = 1e2 * 1e-9
MAX_D = 3e2 * 1e-9
O_MIN_D = 1.5 * MAX_D
O_MAX_D = 4 * MAX_D

MAX_D_COEF = preD / MIN_D
DELTA_T = R**2 / (2 * (N - 1) * MAX_D_COEF) / 1000
COUNT = 1000

def to_xyz(array):
    alpha, r, h = array
    return np.array([array[1] * np.cos(array[0]), array[1] * np.sin(array[0]), h])

def generate_population(size, min_d, max_d):
    if not size:
        return np.zeros((size, 4))
    
    ds = np.random.uniform(min_d, max_d, [size, 1])

    hs = np.random.uniform(ds * 0.5, H - ds * 0.5, [size, 1])
    alphas = np.random.uniform(0, np.pi * 2, [size, 1])
    rs = np.random.uniform(0, R - ds * 0.5, [size, 1])
    
    coords = np.apply_along_axis(to_xyz, 1, np.hstack([alphas, rs, hs]))
    
    return np.hstack([coords, ds])

def generate_population_obsticles(population_size, obsticles_count):
    obsticles = generate_population(obsticles_count, O_MIN_D, O_MAX_D)
    population = []
    for i in range(population_size):
        being = None
        while being is None or np.sum(filter_collisions(being, obsticles)) > 0:
            being = generate_population(1, MIN_D, MAX_D)
        population.append(being)
        
    return np.vstack(population), obsticles

def generate_displacement(generation, delta_t):
    sigmas = np.sqrt(2 * preD / generation[:, 3] * delta_t)
    return np.random.randn(generation.shape[0], generation.shape[1] - 1) * sigmas[:, np.newaxis]

def stay_in_bounds(array):
    z_pos = array[2] + array[-1]
    sqr_r_pos = (array[0] + array[-3]) ** 2 + (array[1] + array[-2]) ** 2
    d2 = array[3] / 2
    
    if 0 <= z_pos - d2 and z_pos + d2 <= H and sqr_r_pos <= (R - d2) ** 2:
        array[:3] += array[-3:]
    return array[:4]

def check_for_out_of_bounds(being):
    first = population[:, N] <= population[:, N - 1]
    second = population[:, N - 1] <= H - population[:, N]
    third = np.linalg.norm(population[:, :N - 1], axis=1) <= R - population[:, N]
    
    return np.logical_not(np.logical_and(first, np.logical_and(second, third)))

def check_for_collisions(being, obsticles):
    return np.linalg.norm(obsticles[:, :N] - being[:N], axis=1) ** 2 < (obsticles[:, N] + being[N]) ** 2
    
def filter_collisions(population, obsticles):
    return np.any(np.apply_along_axis(check_for_collisions, 1, population, obsticles), axis=1)

def build_tracks(population, obsticles, length):
    tracks = np.zeros([population.shape[0], length, N])
    
    for i in range(length):
        tracks[:, i, :] = population[:, :N]
    
        deltas = generate_displacement(population, DELTA_T)
        population[:, :N] += deltas
        need_to_revert = np.logical_or(check_for_out_of_bounds(population), filter_collisions(population, obsticles))
        
        population[:, :N][need_to_revert] -= deltas[need_to_revert]
        
    return tracks

def remove_same(track):
    indexes = np.hstack([[True], np.any(track[1:, :] != track[:-1, :], axis=1)]) 
    return track[indexes]

population, obsticles = generate_population_obsticles(20, 1000)

tracks = build_tracks(population, obsticles, COUNT)

plot_generation(generation, obsticles, 'ro')

fig = plt.figure()
ax = fig.gca()
ax.add_artist(plt.Circle((0, 0), R, color='b'))
for obsticle in obsticles:
    ax.add_artist(plt.Circle(obsticle[:N-1], obsticle[N]))
for track in tracks:
    ax.plot(track[:, 0], track[:, 1])
plt.show()

# %%
def t_function(x, alpha, beta):
    return beta * x**alpha

for track in tracks:
    ys, ss = [], []
    
    track = remove_same(track)
    
    for i in range(35):
        cur = []
        for j in range(track.shape[0] - i):
            cur.append(np.linalg.norm(track[j, :N] - track[j + i, :N]) ** 2)
        ys.append(np.mean(cur))
        ss.append(len(cur))
    ys = np.array(ys)

    xs = arange(len(ys))[:len(ys) // 2]
    ys = ys[xs]

    popt, _ = sp.optimize.curve_fit(t_function, xs, ys, [1, 1])
    print(popt)
    plot(xs, ys)
    plot(xs, t_function(xs, *popt))
    show()
# Out:
# [  9.51945701e-01   8.85662190e-14]
# [  7.08511324e-01   7.60267808e-14]
# [  9.48616448e-01   5.67149044e-14]
# [  8.87156630e-01   1.03595314e-13]
# [  1.00000000e+00   6.29740048e-14]
# [  9.78745114e-01   1.20544438e-13]
# [  9.06284192e-01   8.20379587e-14]
# [  8.85201377e-01   9.92134811e-14]
# [  9.35977714e-01   1.26931901e-13]
# [  8.78039035e-01   7.08037923e-14]
# [  8.88804346e-01   8.91190438e-14]
# [  8.72686698e-01   9.36320187e-14]
# [  9.39090487e-01   6.69696770e-14]
# [  8.35868182e-01   1.02799066e-13]
# [  9.18151836e-01   6.60577038e-14]
# [  8.99969243e-01   5.47000521e-14]
# [  8.55284148e-01   7.72513575e-14]
# [  9.11541801e-01   5.95856118e-14]
# [  8.79190071e-01   8.84983585e-14]
# [  8.53437932e-01   5.72515275e-14]

# %%
COUNT = 10

while True:
    generation = np.hstack([np.zeros((10000000, 3)), MIN_D * np.ones((10000000, 1))])
    for i in range(COUNT):
        deltas = generate_displacement(generation, DELTA_T)
        generation[:, :N] += deltas
#         generation = np.apply_along_axis(stay_in_bounds, 1, np.hstack([generation, deltas]))

    delta_squared = np.linalg.norm(generation[:, :N], axis=1) ** 2
    print(preD / MIN_D, delta_squared.mean() / (2 * N * DELTA_T) / COUNT)
break
# Out:
# 4.290180645985131e-12 4.2916487566e-12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-0e89a724e4d2> in <module>()
#       4     generation = np.hstack([np.zeros((10000000, 3)), MIN_D * np.ones((10000000, 1))])
#       5     for i in range(COUNT):
# ----> 6         deltas = generate_displacement(generation, DELTA_T)
#       7         generation[:, :N] += deltas
#       8 #         generation = np.apply_along_axis(stay_in_bounds, 1, np.hstack([generation, deltas]))
#
# <ipython-input-26-aaad8f1ad5a3> in generate_displacement(generation, delta_t)
#      32 def generate_displacement(generation, delta_t):
#      33     sigmas = np.sqrt(2 * preD / generation[:, 3] * delta_t)
# ---> 34     return np.random.randn(generation.shape[0], generation.shape[1] - 1) * sigmas[:, np.newaxis]
#      35
#      36 def stay_in_bounds(array):
#
# KeyboardInterrupt:
